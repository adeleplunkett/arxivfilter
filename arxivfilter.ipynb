# %% [markdown]
# ## Quick ALMA-centric Arxiv filter
#
# The goal is to find any paper on the astro-ph arxiv that uses ALMA data.
#
# For now, we search for keywords:
# * ALMA
# * mm
# * millimeter
# * millimetre
#
# Results are returned in a table format for a quick look, and also exported to an excel spreadsheet.
#
# ### Suggestions always welcome!

# %%
# %matplotlib inline

# %%
import urllib
try:
    # Python 2
    from urllib import quote_plus
    from urllib import urlencode
    from urllib import urlretrieve
except ImportError:
    # Python 3
    from urllib.parse import quote_plus
    from urllib.parse import urlencode
    from urllib.request import urlretrieve

# %%
import feedparser
import pandas as pd
import numpy as np
import datetime
import time

# %%
#OLDER VERSION:
#url = 'http://export.arxiv.org/api/query?search_query=cat:%s+AND+%%28+all:%s+OR+all:%s+OR+all:%s+OR+all:%s+%%29&start=0&sortBy=submittedDate&sortOrder=descending'%(cat,keywords[0],keywords[1],keywords[2],keywords[3])
#data = urllib.urlopen(url).read()

# %%
## Choose the date range to search
enddate = '201812141159' #enter as yyyymmddhhmm or "today"
startdate = '201811011159' #if nothing, print since one month before enddate 
if enddate == 'today':
    now = datetime.datetime.now()
    enddate = str(now.year)+str(now.month)+str(now.day)+str(now.hour)+str(now.minute)
enddate_as_date = datetime.datetime(int(enddate[0:4]),int(enddate[4:6]),int(enddate[6:8]))
if startdate == '':
    startdate_as_date=enddate_as_date.replace(day=1)
    startdate = str(startdate_as_date.year)+str(startdate_as_date.month)+str(startdate_as_date.day)+str(startdate_as_date.hour)+str(startdate_as_date.minute)
print('Search dates: %s:%s')%(startdate,enddate)
# Out:
# Search dates: 201811011159:201812141159

# %%
## based on code from https://github.com/lukasschwab/arxiv.py/blob/master/arxiv/arxiv.py
root_url = 'http://export.arxiv.org/api/'

def query(search_query="",
         date_from=None, 
         date_until=None,
         id_list=[], 
         prune=True, 
         start=0, 
         max_results=10, 
         sort_by="relevance", 
         sort_order="descending"):
    url_args = urlencode({"id_list": ','.join(id_list),
                          "start": start,
                          "max_results": max_results,
                          "sortBy": sort_by,
                          "sortOrder": sort_order},)
    results = feedparser.parse(root_url + 'query?search_query='+search_query + url_args)
    if results.get('status') != 200:
        # TODO: better error reporting
        raise Exception("HTTP Error " + str(results.get('status', 'no status')) + " in query")
    else:
        results = results['entries']

    return results

# %%
## Make a query
cat = 'astro-ph*'
## Here are keywords from title/abstract (full text?)
keywords = ['ALMA','millimeter','millimetre','mm']
## You could also query authors using au:authorname
sq = 'cat:%s+AND+%%28+all:%s+OR+all:%s+OR+all:%s+OR+all:%s+%%29+AND+submittedDate:[%s+TO+%s]&'\
    %(cat,keywords[0],keywords[1],keywords[2],keywords[3],startdate,enddate)
num_results = 200
results=query(search_query=sq,sort_by='submittedDate',sort_order='descending',max_results=num_results)

# %% [markdown]
# **IMPORTANT NOTE**
#
# These are not curated.  They may have *nothing* to do with ALMA, but simply have a keyword 'mm'.
#
# Later I will curate them myself as we go, and save them to a google spreadsheet (or elsewhere).

# %%
## NOW convert to dataframe for better table processing
posts = []
columns=['published','title','authors','summary','link','arxiv_primary_category','arxiv_comment']

for pp in np.arange(np.size(results)):
        try: comment=results[pp][columns[6]]
        except: comment=''  
        authorlist=[]
        for elem in results[pp][columns[2]]:
            authorlist.append(elem['name'])
        posts.append((results[pp][columns[0]], results[pp][columns[1]]\
                     , results[pp][columns[2]][0]['name'], authorlist\
                     , results[pp][columns[3]], results[pp][columns[4]]\
                     , results[pp][columns[5]]['term'], comment))
        
df = pd.DataFrame(posts, columns=[columns[0],columns[1],columns[2],'author list',columns[3],columns[4],columns[5],columns[6]]) # pass data to init

# %%
## LOOK at the table
df
# Out:
#                 published                                              title  \
# 0    2018-12-13T12:40:02Z  ALMA Observations of the Molecular Gas in the ...
# 1    2018-12-12T01:50:41Z  Dust formation in embryonic pulsar-aided super...
# 2    2018-12-11T16:50:11Z  The Disk Substructures at High Angular Resolut...
# 3    2018-12-11T12:36:38Z  Warm dust surface chemistry in protoplanetary ...
# 4    2018-12-11T10:20:49Z  Kinetic energy transfer from X-ray ultrafast o...
# 5    2018-12-11T02:40:56Z  The Disk Substructures at High Angular Resolut...
# 6    2018-12-10T22:01:53Z  The Planet Formation Potential Around a 45 Myr...
# 7    2018-12-10T21:37:51Z  Multi-band Optical and Near-infrared Propertie...
# 8    2018-12-10T20:02:16Z  Gas density perturbations induced by forming p...
# 9    2018-12-10T19:37:57Z  The Disk Substructures at High Angular Resolut...
# 10   2018-12-10T19:36:32Z  The Disk Substructures at High Angular Resolut...
# 11   2018-12-10T19:36:00Z  Disk Substructures at High Angular Resolution ...
# 12   2018-12-10T19:35:34Z  The Disk Substructures at High Angular Resolut...
# 13   2018-12-10T19:34:17Z  The Disk Substructures at High Angular Resolut...
# 14   2018-12-10T19:33:33Z  The Disk Substructures at High Angular Resolut...
# 15   2018-12-10T19:31:57Z  The Disk Substructures at High Angular Resolut...
# 16   2018-12-10T19:31:24Z  The Disk Substructures at High Angular Resolut...
# 17   2018-12-10T13:37:49Z  Reflectometry Measurements of the Loss Tangent...
# 18   2018-12-10T09:55:28Z  ALMA Observations of Ethyl Formate toward Orio...
# 19   2018-12-10T09:21:12Z  The STRIP instrument of the Large Scale Polari...
# 20   2018-12-09T23:12:33Z  Wideband 67-116 GHz cryogenic receiver develop...
# 21   2018-12-07T19:21:44Z  ALMA High Angular Resolution Polarization Stud...
# 22   2018-12-06T19:26:58Z  Chandra Detection of the Circumnuclear Molecul...
# 23   2018-12-06T13:15:57Z  Consistent dust and gas models for protoplanet...
# 24   2018-12-06T10:53:54Z  Deuterated methyl mercaptan (CH$_3$SD): Labora...
# 25   2018-12-05T19:44:42Z  A flexible GPU-accelerated radio-frequency rea...
# 26   2018-12-05T19:23:23Z  The magnetic field structure in CTA 102 from h...
# 27   2018-12-05T19:00:03Z  ALMA Observations of Giant Molecular Clouds in...
# 28   2018-12-04T07:58:45Z  Inclined Massive Planets in a Protoplanetary D...
# 29   2018-12-04T03:10:44Z  Synthetic observations of H$_2$D$^+$ towards h...
# ..                    ...                                                ...
# 81   2018-11-09T19:50:39Z  Discovery of δ Scuti Pulsations in the Young H...
# 82   2018-11-09T15:41:53Z  ALMA detections of the youngest protostars in ...
# 83   2018-11-08T19:00:33Z                    Super-Earths in the TW Hya disc
# 84   2018-11-08T18:59:08Z  Meter- to Millimeter Emission from Cool Stella...
# 85   2018-11-07T19:00:01Z  Dust Polarization Toward Embedded Protostars i...
# 86   2018-11-07T18:41:06Z  The ALMA Lupus protoplanetary disk survey: evi...
# 87   2018-11-07T18:20:50Z  The Formation Conditions of the Wide Binary Cl...
# 88   2018-11-07T16:32:30Z  ALMA observations of massive molecular gas res...
# 89   2018-11-07T14:40:09Z  Constraints on Compound Chondrule Formation fr...
# 90   2018-11-07T14:09:42Z  The Ring Structure in the MWC 480 Disk Reveale...
# 91   2018-11-07T13:27:04Z  Herschel-ATLAS : The spatial clustering of low...
# 92   2018-11-06T22:03:06Z  Molecular ion abundances in the diffuse ISM : ...
# 93   2018-11-06T12:15:52Z  Astrophysics with the Spatially and Spectrally...
# 94   2018-11-06T11:32:25Z  Thermal architecture for the QUBIC cryogenic r...
# 95   2018-11-06T06:55:46Z  Spectral Energy Distribution of the inner accr...
# 96   2018-11-05T19:00:05Z  Constraining the evolution of CII intensity th...
# 97   2018-11-05T18:00:00Z  SMA line observations of the CH$_3$OH-maser ou...
# 98   2018-11-05T12:54:00Z  First ALMA maps of HCO, an important precursor...
# 99   2018-11-05T10:52:28Z  Evolution of the flow field in decaying active...
# 100  2018-11-04T21:39:19Z                     Status of Astronomy in Namibia
# 101  2018-11-02T17:01:39Z  ALMA observations of molecular tori around mas...
# 102  2018-11-02T12:42:46Z  Millimeter line observations toward four local...
# 103  2018-11-02T10:49:38Z  An ALMA view of molecular filaments in the Lar...
# 104  2018-11-02T10:40:21Z  Catalog of supermassive black holes for interf...
# 105  2018-11-02T07:56:31Z  Modelling the abundance structure of isocyanic...
# 106  2018-11-02T07:20:56Z  SS433's jet trace from ALMA imaging and Global...
# 107  2018-11-01T22:49:10Z  Exploring the Influence of Density Contrast on...
# 108  2018-11-01T18:07:33Z                 Radio galaxies - the TeV challenge
# 109  2018-11-01T17:43:24Z         How planetary growth outperforms migration
# 110  2018-11-01T14:39:30Z  Deep ALMA Search for CO Gas in the HD 95086 De...
#
#                      authors  \
# 0             B. Vila-Vilaro
# 1                Conor Omand
# 2           Nicolás Kurtovic
# 3                  W. F. Thi
# 4            Misaki Mizumoto
# 5                 Jane Huang
# 6          Kevin M. Flaherty
# 7              Pallavi Patil
# 8               Cécile Favre
# 9             Laura M. Pérez
# 10             Andrea Isella
# 11         Viviana V. Guzmán
# 12            Shangjia Zhang
# 13     Cornelis P. Dullemond
# 14          Tilman Birnstiel
# 15                Jane Huang
# 16           Sean M. Andrews
# 17         Grace E. Chesmore
# 18               Yaping Peng
# 19            C. Franceschet
# 20               P. Yagoubov
# 21          Satoko Takahashi
# 22               G. Fabbiano
# 23                 P. Woitke
# 24          Olena Zakharenko
# 25          Lorenzo Minutolo
# 26          Carolina Casadio
# 27                 Nia Imara
# 28              Zhaohuan Zhu
# 29                J. Zamponi
# ..                       ...
# 81          Samuel N. Mellon
# 82         Rachel K. Friesen
# 83          Daniel Mentiplay
# 84              Jan Forbrich
# 85          Sarah I. Sadavoy
# 86        S. E. van Terwisga
# 87                John Tobin
# 88              A. E. Sansom
# 89              Tabea Bogdan
# 90                   Yao Liu
# 91            A. Amvrosiadis
# 92                  M. Gerin
# 93          Tony Mroczkowski
# 94                 A. J. May
# 95                 Ren-Yi Ma
# 96         Hamsa Padmanabhan
# 97    Ma. T. Orozco-Aguilera
# 98             V. M. Rivilla
# 99            Hanna Strecker
# 100                M. Backes
# 101                F. Combes
# 102                   Fei Li
# 103              Yasuo Fukui
# 104           E. V. Mikheeva
# 105  Antonio Hernández-Gómez
# 106       Katherine Blundell
# 107        Loren I. Matilsky
# 108                  B. Rani
# 109          Anders Johansen
# 110               Mark Booth
#
#                                            author list  \
# 0    [B. Vila-Vilaro, D. Espada, P. Cortes, S. Leon...
# 1        [Conor Omand, Kazumi Kashiyama, Kohta Murase]
# 2    [Nicolás Kurtovic, Laura Pérez, Myriam Benisty...
# 3    [W. F. Thi, S. Hocuk, I. Kamp, P. Woitke, Ch. ...
# 4        [Misaki Mizumoto, Takuma Izumi, Kotaro Kohno]
# 5    [Jane Huang, Sean M. Andrews, Laura M. Pérez, ...
# 6    [Kevin M. Flaherty, A. Meredith Hughes, Eric E...
# 7    [Pallavi Patil, Kristina Nyland, Mark Lacy, Du...
# 8    [Cécile Favre, Davide Fedele, Luke Maud, Richa...
# 9    [Laura M. Pérez, Myriam Benisty, Sean M. Andre...
# 10   [Andrea Isella, Jane Huang, Sean M. Andrews, C...
# 11   [Viviana V. Guzmán, Jane Huang, Sean M. Andrew...
# 12   [Shangjia Zhang, Zhaohuan Zhu, Jane Huang, Viv...
# 13   [Cornelis P. Dullemond, Tilman Birnstiel, Jane...
# 14   [Tilman Birnstiel, Cornelis P. Dullemond, Zhao...
# 15   [Jane Huang, Sean M. Andrews, Cornelis P. Dull...
# 16   [Sean M. Andrews, Jane Huang, Laura M. Pérez, ...
# 17   [Grace E. Chesmore, Tony Mroczkowski, Jeff McM...
# 18   [Yaping Peng, V. M. Rivilla, Li Zhang, J. X. G...
# 19   [C. Franceschet, S. Realini, A. Mennella, G. A...
# 20   [P. Yagoubov, T. Mroczkowski, L. Testi, C. De ...
# 21   [Satoko Takahashi, Masahiro N. Machida, Kohji ...
# 22   [G. Fabbiano, A. Paggi, A. Siemiginowska, M. E...
# 23   [P. Woitke, I. Kamp, S. Antonellini, F. Anthon...
# 24   [Olena Zakharenko, Frank Lewen, Vadim V. Ilyus...
# 25   [Lorenzo Minutolo, Bryan Steinbach, Albert Wan...
# 26   [Carolina Casadio, Alan P. Marscher, Svetlana ...
# 27                   [Nia Imara, Christopher M. Faesi]
# 28                                      [Zhaohuan Zhu]
# 29   [J. Zamponi, D. R. G. Schleicher, S. Bovino, A...
# ..                                                 ...
# 81   [Samuel N. Mellon, Eric E. Mamajek, Konstanze ...
# 82   [Rachel K. Friesen, Andy Pon, Tyler L. Bourke,...
# 83   [Daniel Mentiplay, Daniel J. Price, Christophe...
# 84   [Jan Forbrich, Peter K. G. Williams, Emily Dra...
# 85   [Sarah I. Sadavoy, Philip C. Myers, Ian W. Ste...
# 86   [S. E. van Terwisga, E. F. van Dishoeck, P. Ca...
# 87   [John Tobin, Tyler Bourke, Stacy Mader, Lars K...
# 88   [A. E. Sansom, D. H. W. Glass, G. J. Bendo, T....
# 89   [Tabea Bogdan, Jens Teiser, Nikolai Fischer, M...
# 90   [Yao Liu, Giovanni Dipierro, Enrico Ragusa, Gi...
# 91   [A. Amvrosiadis, E. Valiante, J. Gonzalez-Nuev...
# 92   [M. Gerin, H. Liszt, D. Neufeld, B. Godard, P....
# 93   [Tony Mroczkowski, Daisuke Nagai, Kaustuv Basu...
# 94   [A. J. May, C. Chapron, G. Coppi, G. D'Alessan...
# 95   [Ren-Yi Ma, Shawn R. Roberts, Ya-Ping Li, Q. D...
# 96                                 [Hamsa Padmanabhan]
# 97   [Ma. T. Orozco-Aguilera, Antonio Hernández-Góm...
# 98   [V. M. Rivilla, M. T. Beltrán, A. Vasyunin, P....
# 99            [Hanna Strecker, Nazaret Bello González]
# 100   [M. Backes, R. Evans, E. K. Kasai, R. Steenkamp]
# 101  [F. Combes, S. Garcia-Burillo, A. Audibert, L....
# 102    [Fei Li, Junzhi Wang, Minzhi Kong, Shanghuo Li]
# 103  [Yasuo Fukui, Kazuki Tokuda, Kazuya Saigo, Ryo...
# 104  [E. V. Mikheeva, V. N. Lukash, S. V. Repin, A....
# 105  [Antonio Hernández-Gómez, Emna Sahnoun, Emmanu...
# 106  [Katherine Blundell, Robert Laing, Steven Lee,...
# 107  [Loren I. Matilsky, Bradley W. Hindman, Juri T...
# 108                                          [B. Rani]
# 109      [Anders Johansen, Shigeru Ida, Ramon Brasser]
# 110  [Mark Booth, Luca Matrà, Kate Y. L. Su, Quenti...
#
#                                                summary  \
# 0    We present the results of CO interferometric o...
# 1    We investigate effects of energetic pulsar win...
# 2    To characterize the substructures induced in p...
# 3    The origin of the reservoirs of water on Earth...
# 4    UltraFast Outflows (UFOs), seen as X-ray blues...
# 5    We present an analysis of ALMA 1.25 millimeter...
# 6    Debris disk detections around M dwarfs are rar...
# 7    We present a catalog of 26 faint submillimeter...
# 8    The formation of planets occurs within protopl...
# 9    We present a detailed analysis of new ALMA obs...
# 10   ALMA observations of protoplanetary disks acqu...
# 11   We present a detailed analysis of the high-ang...
# 12   The Disk Substructures at High Angular Resolut...
# 13   A large fraction of the protoplanetary disks o...
# 14   The Disk Substructures at High Angular Resolut...
# 15   The Disk Substructures at High Angular Resolut...
# 16   We introduce the Disk Substructures at High An...
# 17   We report here on measurements of the reflecti...
# 18   Orion KL is one of the prime templates of astr...
# 19   In this paper we discuss the latest developmen...
# 20   The Atacama Large Millimeter/sub-millimeter Ar...
# 21   Using the $\approx$15km ALMA long baselines, w...
# 22   We report a clumpy elongated feature found wit...
# 23   The European FP7 project DIANA has performed a...
# 24   Methyl mercaptan (also known as methanethiol),...
# 25   We have developed a flexible radio-frequency r...
# 26   Investigating the magnetic field structure in ...
# 27   We present new ${}^{12}$CO(J=1-0) observations...
# 28   We carry out three-dimensional hydrodynamical ...
# 29   Young massive stars are usually found embedded...
# ..                                                 ...
# 81   The bRing robotic observatory network was buil...
# 82   We present Atacama Large Millimeter/submillime...
# 83   We test the hypothesis that the sub-millimetre...
# 84   Radio observations of cool stellar systems pro...
# 85   We present high resolution (~ 35 au) ALMA Band...
# 86   The cyanide radical CN is abundant in protopla...
# 87   We present a characterization of the binary pr...
# 88   Unresolved gas and dust observations show a su...
# 89   In laboratory experiments, spherical 1 mm-wide...
# 90   Gap-like structures in protoplanetary disks ar...
# 91   We present measurements of the angular correla...
# 92   The transition between atomic and molecular hy...
# 93   In recent years, observations of the Sunyaev-Z...
# 94   QUBIC, the QU Bolometric Interferometer for Co...
# 95   Sgr A* represents a unique laboratory for the ...
# 96   We combine available constraints on the local ...
# 97   We present a (sub)millimeter line survey of th...
# 98   The formyl radical HCO has been proposed as th...
# 99   We investigate the evolution of the horizontal...
# 100  Astronomy plays a major role in the scientific...
# 101  We report ALMA observations of CO(3-2) emissio...
# 102  We present results of millimeter line observat...
# 103  We present the ALMA observations of CO isotope...
# 104  The paper presents a catalog of supermassive b...
# 105  Isocyanic acid (HNCO), the most stable of the ...
# 106  We present a comparison of Doppler-shifted H-a...
# 107  The advent of helioseismology has determined i...
# 108  Over the past decade, our knowledge of the \ga...
# 109  Planetary migration is a major challenge for p...
# 110  One of the defining properties of debris discs...
#
#                                   link arxiv_primary_category  \
# 0    http://arxiv.org/abs/1812.05385v1            astro-ph.GA
# 1    http://arxiv.org/abs/1812.04773v1            astro-ph.HE
# 2    http://arxiv.org/abs/1812.04536v1            astro-ph.SR
# 3    http://arxiv.org/abs/1812.04357v1            astro-ph.GA
# 4    http://arxiv.org/abs/1812.04316v1            astro-ph.GA
# 5    http://arxiv.org/abs/1812.04193v1            astro-ph.SR
# 6    http://arxiv.org/abs/1812.04124v1            astro-ph.SR
# 7    http://arxiv.org/abs/1812.04108v1            astro-ph.GA
# 8    http://arxiv.org/abs/1812.04062v1            astro-ph.EP
# 9    http://arxiv.org/abs/1812.04049v1            astro-ph.SR
# 10   http://arxiv.org/abs/1812.04047v1            astro-ph.SR
# 11   http://arxiv.org/abs/1812.04046v1            astro-ph.SR
# 12   http://arxiv.org/abs/1812.04045v1            astro-ph.EP
# 13   http://arxiv.org/abs/1812.04044v1            astro-ph.EP
# 14   http://arxiv.org/abs/1812.04043v1            astro-ph.SR
# 15   http://arxiv.org/abs/1812.04041v1            astro-ph.EP
# 16   http://arxiv.org/abs/1812.04040v1            astro-ph.SR
# 17   http://arxiv.org/abs/1812.03785v1            astro-ph.IM
# 18   http://arxiv.org/abs/1812.03700v1            astro-ph.SR
# 19   http://arxiv.org/abs/1812.03687v1            astro-ph.IM
# 20   http://arxiv.org/abs/1812.03575v1            astro-ph.IM
# 21   http://arxiv.org/abs/1812.03189v1            astro-ph.GA
# 22   http://arxiv.org/abs/1812.02764v1            astro-ph.HE
# 23   http://arxiv.org/abs/1812.02741v1            astro-ph.EP
# 24   http://arxiv.org/abs/1812.02454v1            astro-ph.SR
# 25   http://arxiv.org/abs/1812.02200v1            astro-ph.IM
# 26   http://arxiv.org/abs/1812.02194v1            astro-ph.HE
# 27   http://arxiv.org/abs/1812.02180v1            astro-ph.GA
# 28   http://arxiv.org/abs/1812.01262v1            astro-ph.EP
# 29   http://arxiv.org/abs/1812.01191v2            astro-ph.GA
# ..                                 ...                    ...
# 81   http://arxiv.org/abs/1811.04118v3            astro-ph.SR
# 82   http://arxiv.org/abs/1811.03976v1            astro-ph.SR
# 83   http://arxiv.org/abs/1811.03636v1            astro-ph.EP
# 84   http://arxiv.org/abs/1811.03616v1            astro-ph.SR
# 85   http://arxiv.org/abs/1811.03104v1            astro-ph.GA
# 86   http://arxiv.org/abs/1811.03071v1            astro-ph.SR
# 87   http://arxiv.org/abs/1811.03059v1            astro-ph.GA
# 88   http://arxiv.org/abs/1811.02967v1            astro-ph.GA
# 89   http://arxiv.org/abs/1811.02905v1            astro-ph.EP
# 90   http://arxiv.org/abs/1811.04074v1            astro-ph.EP
# 91   http://arxiv.org/abs/1811.02870v1            astro-ph.GA
# 92   http://arxiv.org/abs/1811.02679v2            astro-ph.GA
# 93   http://arxiv.org/abs/1811.02310v3            astro-ph.CO
# 94   http://arxiv.org/abs/1811.02296v1            astro-ph.IM
# 95   http://arxiv.org/abs/1811.02190v1            astro-ph.HE
# 96   http://arxiv.org/abs/1811.01968v2            astro-ph.CO
# 97   http://arxiv.org/abs/1811.01880v1            astro-ph.SR
# 98   http://arxiv.org/abs/1811.01650v1            astro-ph.GA
# 99   http://arxiv.org/abs/1811.01607v1            astro-ph.SR
# 100  http://arxiv.org/abs/1811.01440v1            astro-ph.IM
# 101  http://arxiv.org/abs/1811.00984v1            astro-ph.GA
# 102  http://arxiv.org/abs/1811.00838v1            astro-ph.GA
# 103  http://arxiv.org/abs/1811.00812v2            astro-ph.GA
# 104  http://arxiv.org/abs/1811.00808v1            astro-ph.GA
# 105  http://arxiv.org/abs/1811.00766v1            astro-ph.SR
# 106  http://arxiv.org/abs/1811.00760v1            astro-ph.HE
# 107  http://arxiv.org/abs/1811.00665v1            astro-ph.SR
# 108  http://arxiv.org/abs/1811.00567v1            astro-ph.HE
# 109  http://arxiv.org/abs/1811.00523v1            astro-ph.EP
# 110  http://arxiv.org/abs/1811.00412v1            astro-ph.EP
#
#                                          arxiv_comment
# 0
# 1    17 pages, 10 figures, submitted to MNRAS, comm...
# 2        15 pages, 10 figures, accepted to ApJ Letters
# 3                                      accepted to A&A
# 4    13 pages, 7 figures, accepted for publication ...
# 5                19 pages, 9 figures, accepted by ApJL
# 6                  9 pages, 4 figures, accepted to ApJ
# 7    Accepted for publication in ApJ, 32 pages, 11 ...
# 8                      Accepted for publication by ApJ
# 9    15 pages, 8 figures, accepted for publication ...
# 10         ApJ Letters, in press. 19 pages, 11 figures
# 11                               ApJ Letters, in press
# 12         36 pages, 22 figures, ApJ Letters, in press
# 13             Accepted for publication in ApJ Letters
# 14                               ApJ Letters, in press
# 15   33 pages, 12 figures, accepted by ApJL. Table ...
# 16   ApJ Letters, in press; some figure resolutions...
# 17   6 pages, proceedings from the 8th ESA Workshop...
# 18
# 19   17 pages, 15 figures, proceedings of the SPIE ...
# 20   8 pages, proceedings from the 8th ESA Workshop...
# 21   47 pages, 9 figures, 4 tables, Accepted for pu...
# 22                               ApJ Letters, in press
# 23   70 pages, 35 figures, 22 tables, accepted by PASP
# 24               Astron. Astrophys., in press; 8 pages
# 25   Submitted to IEEE Transactions on Superconduct...
# 26   Accepted for publication in Astronomy & Astrop...
# 27
# 28   21 pages, 20 figures, accepted for publication...
# 29   3 pages, 3 figures, To appear in the proceedin...
# ..                                                 ...
# 81      Accepted by ApJ, 15 pages, 7 figures, 6 tables
# 82               19 pages, 10 figures, accepted to ApJ
# 83   6 pages, 5 figures, accepted for publication i...
# 84   Splinter session summary, to appear in the pro...
# 85                Accepted to ApJ, 15 pages, 9 figures
# 86                  22 pages, 14 figures, A&A accepted
# 87     51 pages, 25 Figures, 2 Tables, Accepted to ApJ
# 88   15 pages, 10 figures, 3 tables, accepted for p...
# 89
# 90   Accepted for publication in A&A, 11 pages, 8 f...
# 91   17 pages, 11 figures, 3 tables. Accepted for p...
# 92   15 pages, 9 Figures, accepted by Astronomy and...
# 93   67 pages. Review paper. Submitted to Space Sci...
# 94
# 95   10 pages, 8 figures, 1 table, accepted for pub...
# 96   9 pages, 9 figures, 2 tables; v2: clarificatio...
# 97                Accepted by the Astronomical Journal
# 98   Accepted in Monthly Notices of the Royal Astro...
# 99   accepted for publication in A&A, 11 pages, 6 f...
# 100  6 pages, 4 figures. Published version availabl...
# 101  18 pages, 21 figures, submitted to Astron. and...
# 102  15pages, 13 figures; accepted for publication ...
# 103              13 pages, 6 figures, submitted to ApJ
# 104  17 pages, 3 figures, 2 tables. Accepted for pu...
# 105
# 106                           To appear in ApJ Letters
# 107  5 pages, 6 figures; In the 20th Cambridge Work...
# 108  Invited review article, submitted to Galaxies;...
# 109  Submitted to Astronomy & Astrophysics, revised...
# 110             11 pages, 7 figures, accepted to MNRAS
#
# [111 rows x 8 columns]

# %%
## WRITE to excel
writer = pd.ExcelWriter('testoutput.xlsx')
df.to_excel(writer,'Sheet1')
writer.save()

# %% [markdown]
# ** TO DO **
#
# Better select of range of dates https://github.com/Mahdisadjadi/arxivscraper/blob/master/arxivscraper/arxivscraper.py
# --> Works, but gets confused between single and double digit dates.
#
# Then sync directly with Google sheets (or github?)
# https://github.com/burnash/gspread
# https://github.com/robin900/gspread-dataframe
