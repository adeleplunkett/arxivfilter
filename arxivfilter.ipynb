# %% [markdown]
# ## Quick ALMA-centric Arxiv filter
#
# The goal is to find any paper on the astro-ph arxiv that uses ALMA data.
#
# For now, we search for keywords:
# * ALMA
# * mm
# * millimeter
# * millimetre
#
# Results are returned in a table format for a quick look, and also exported to an excel spreadsheet.
#
# ### Suggestions always welcome!

# %%
# %matplotlib inline

# %%
import urllib
try:
    # Python 2
    from urllib import quote_plus
    from urllib import urlencode
    from urllib import urlretrieve
except ImportError:
    # Python 3
    from urllib.parse import quote_plus
    from urllib.parse import urlencode
    from urllib.request import urlretrieve

# %%
import feedparser # (you may need to install this: conda install feedparser)
import pandas as pd
import numpy as np
import datetime
import time

# %%
#OLDER VERSION:
#url = 'http://export.arxiv.org/api/query?search_query=cat:%s+AND+%%28+all:%s+OR+all:%s+OR+all:%s+OR+all:%s+%%29&start=0&sortBy=submittedDate&sortOrder=descending'%(cat,keywords[0],keywords[1],keywords[2],keywords[3])
#data = urllib.urlopen(url).read()

# %%
## Choose the date range to search
enddate = '201812141159' #enter as yyyymmddhhmm or "today"
startdate = '201811011159' #if nothing, print since one month before enddate 
if enddate == 'today':
    now = datetime.datetime.now()
    enddate = str(now.year)+str(now.month)+str(now.day)+str(now.hour)+str(now.minute)
enddate_as_date = datetime.datetime(int(enddate[0:4]),int(enddate[4:6]),int(enddate[6:8]))
if startdate == '':
    startdate_as_date=enddate_as_date.replace(day=1)
    startdate = str(startdate_as_date.year)+str(startdate_as_date.month)+str(startdate_as_date.day)+str(startdate_as_date.hour)+str(startdate_as_date.minute)
#print('Search dates: %s:%s')%(startdate,enddate) #python2
print('Search dates: {}:{}'.format(startdate,enddate)) #python3
# Out:
# Search dates: 201811011159:201812141159

# %%
## based on code from https://github.com/lukasschwab/arxiv.py/blob/master/arxiv/arxiv.py
root_url = 'http://export.arxiv.org/api/'

def query(search_query="",
         date_from=None, 
         date_until=None,
         id_list=[], 
         prune=True, 
         start=0, 
         max_results=10, 
         sort_by="relevance", 
         sort_order="descending"):
    url_args = urlencode({"id_list": ','.join(id_list),
                          "start": start,
                          "max_results": max_results,
                          "sortBy": sort_by,
                          "sortOrder": sort_order},)
    results = feedparser.parse(root_url + 'query?search_query='+search_query + url_args)
    if results.get('status') != 200:
        # TODO: better error reporting
        raise Exception("HTTP Error " + str(results.get('status', 'no status')) + " in query")
    else:
        results = results['entries']

    return results

# %%
## Make a query
cat = 'astro-ph*'
## Here are keywords from title/abstract (full text?)
keywords = ['ALMA','millimeter','millimetre','mm']
## You could also query authors using au:authorname
sq = 'cat:%s+AND+%%28+all:%s+OR+all:%s+OR+all:%s+OR+all:%s+%%29+AND+submittedDate:[%s+TO+%s]&'\
    %(cat,keywords[0],keywords[1],keywords[2],keywords[3],startdate,enddate)
num_results = 200
results=query(search_query=sq,sort_by='submittedDate',sort_order='descending',max_results=num_results)

# %% [markdown]
# **IMPORTANT NOTE**
#
# These are not curated.  They may have *nothing* to do with ALMA, but simply have a keyword 'mm'.
#
# Later I will curate them myself as we go, and save them to a google spreadsheet (or elsewhere).

# %%
## NOW convert to dataframe for better table processing
posts = []
columns=['published','title','authors','summary','link','arxiv_primary_category','arxiv_comment']

for pp in np.arange(np.size(results)):
        try: comment=results[pp][columns[6]]
        except: comment=''  
        authorlist=[]
        for elem in results[pp][columns[2]]:
            authorlist.append(elem['name'])
        posts.append((results[pp][columns[0]], results[pp][columns[1]]\
                     , results[pp][columns[2]][0]['name'], authorlist\
                     , results[pp][columns[3]], results[pp][columns[4]]\
                     , results[pp][columns[5]]['term'], comment))
        
df = pd.DataFrame(posts, columns=[columns[0],columns[1],columns[2],'author list',columns[3],columns[4],columns[5],columns[6]]) # pass data to init

# %%
## LOOK at the table
df
# Out:
#                 published                                              title  \
# 0    2018-12-14T05:23:23Z                       An introduction to FITSWebQL
# 1    2018-12-13T19:00:00Z  ALMA Detection of Extended Millimeter Halos in...
# 2    2018-12-13T12:40:02Z  ALMA Observations of the Molecular Gas in the ...
# 3    2018-12-13T09:08:06Z  Dark Matter in the Central Region of the Spira...
# 4    2018-12-12T01:50:41Z  Dust formation in embryonic pulsar-aided super...
# 5    2018-12-11T16:50:11Z  The Disk Substructures at High Angular Resolut...
# 6    2018-12-11T12:36:38Z  Warm dust surface chemistry in protoplanetary ...
# 7    2018-12-11T10:20:49Z  Kinetic energy transfer from X-ray ultrafast o...
# 8    2018-12-11T02:40:56Z  The Disk Substructures at High Angular Resolut...
# 9    2018-12-10T22:01:53Z  The Planet Formation Potential Around a 45 Myr...
# 10   2018-12-10T21:37:51Z  Multi-band Optical and Near-infrared Propertie...
# 11   2018-12-10T20:02:16Z  Gas density perturbations induced by forming p...
# 12   2018-12-10T19:37:57Z  The Disk Substructures at High Angular Resolut...
# 13   2018-12-10T19:36:32Z  The Disk Substructures at High Angular Resolut...
# 14   2018-12-10T19:36:00Z  Disk Substructures at High Angular Resolution ...
# 15   2018-12-10T19:35:34Z  The Disk Substructures at High Angular Resolut...
# 16   2018-12-10T19:34:17Z  The Disk Substructures at High Angular Resolut...
# 17   2018-12-10T19:33:33Z  The Disk Substructures at High Angular Resolut...
# 18   2018-12-10T19:31:57Z  The Disk Substructures at High Angular Resolut...
# 19   2018-12-10T19:31:24Z  The Disk Substructures at High Angular Resolut...
# 20   2018-12-10T13:37:49Z  Reflectometry Measurements of the Loss Tangent...
# 21   2018-12-10T09:55:28Z  ALMA Observations of Ethyl Formate toward Orio...
# 22   2018-12-10T09:21:12Z  The STRIP instrument of the Large Scale Polari...
# 23   2018-12-09T23:12:33Z  Wideband 67-116 GHz cryogenic receiver develop...
# 24   2018-12-07T19:21:44Z  ALMA High Angular Resolution Polarization Stud...
# 25   2018-12-06T19:26:58Z  Chandra Detection of the Circumnuclear Molecul...
# 26   2018-12-06T13:15:57Z  Consistent dust and gas models for protoplanet...
# 27   2018-12-06T10:53:54Z  Deuterated methyl mercaptan (CH$_3$SD): Labora...
# 28   2018-12-05T19:44:42Z  A flexible GPU-accelerated radio-frequency rea...
# 29   2018-12-05T19:23:23Z  The magnetic field structure in CTA 102 from h...
# 18   The Disk Substructures at High Angular Resolut...
# 19   We introduce the Disk Substructures at High An...
# 20   We report here on measurements of the reflecti...
# 21   Orion KL is one of the prime templates of astr...
# 22   In this paper we discuss the latest developmen...
# 23   The Atacama Large Millimeter/sub-millimeter Ar...
# 24   Using the $\approx$15km ALMA long baselines, w...
# 25   We report a clumpy elongated feature found wit...
# 26   The European FP7 project DIANA has performed a...
# 27   Methyl mercaptan (also known as methanethiol),...
# 28   We have developed a flexible radio-frequency r...
# 29   Investigating the magnetic field structure in ...
# ..                                                 ...
# 85   The bRing robotic observatory network was buil...
# 86   We present Atacama Large Millimeter/submillime...
# 87   We test the hypothesis that the sub-millimetre...
# 88   Radio observations of cool stellar systems pro...
# 89   We present high-resolution (~ 35 au) ALMA Band...
# 90   The cyanide radical CN is abundant in protopla...
# 91   We present a characterization of the binary pr...
# 92   Unresolved gas and dust observations show a su...
# 93   In laboratory experiments, spherical 1 mm-wide...
# 94   Gap-like structures in protoplanetary disks ar...
# 95   We present measurements of the angular correla...
# 96   The transition between atomic and molecular hy...
# 97   In recent years, observations of the Sunyaev-Z...
# 98   QUBIC, the QU Bolometric Interferometer for Co...
# 99   Sgr A* represents a unique laboratory for the ...
# 100  We combine available constraints on the local ...
# 101  We present a (sub)millimeter line survey of th...
# 102  The formyl radical HCO has been proposed as th...
# 103  We investigate the evolution of the horizontal...
# 104  Astronomy plays a major role in the scientific...
# 105  We report ALMA observations of CO(3-2) emissio...
# 106  We present results of millimeter line observat...
# 107  We present the ALMA observations of CO isotope...
# 108  The paper presents a catalog of supermassive b...
# 109  Isocyanic acid (HNCO), the most stable of the ...
# 110  We present a comparison of Doppler-shifted H-a...
# 111  The advent of helioseismology has determined i...
# 112  Over the past decade, our knowledge of the \ga...
# 113  Planetary migration is a major challenge for p...
# 114  One of the defining properties of debris discs...
#
#                                   link arxiv_primary_category  \
# 0    http://arxiv.org/abs/1812.05787v1            astro-ph.IM
# 1    http://arxiv.org/abs/1812.05610v1            astro-ph.EP
# 2    http://arxiv.org/abs/1812.05385v1            astro-ph.GA
# 3    http://arxiv.org/abs/1812.05918v1            astro-ph.GA
# 4    http://arxiv.org/abs/1812.04773v1            astro-ph.HE
# 5    http://arxiv.org/abs/1812.04536v1            astro-ph.SR
# 6    http://arxiv.org/abs/1812.04357v1            astro-ph.GA
# 7    http://arxiv.org/abs/1812.04316v1            astro-ph.GA
# 8    http://arxiv.org/abs/1812.04193v1            astro-ph.SR
# 9    http://arxiv.org/abs/1812.04124v1            astro-ph.SR
# 10   http://arxiv.org/abs/1812.04108v1            astro-ph.GA
# 11   http://arxiv.org/abs/1812.04062v1            astro-ph.EP
# 12   http://arxiv.org/abs/1812.04049v1            astro-ph.SR
# 13   http://arxiv.org/abs/1812.04047v1            astro-ph.SR
# 14   http://arxiv.org/abs/1812.04046v1            astro-ph.SR
# 15   http://arxiv.org/abs/1812.04045v1            astro-ph.EP
# 16   http://arxiv.org/abs/1812.04044v1            astro-ph.EP
# 17   http://arxiv.org/abs/1812.04043v1            astro-ph.SR
# 18   http://arxiv.org/abs/1812.04041v1            astro-ph.EP
# 19   http://arxiv.org/abs/1812.04040v1            astro-ph.SR
# 20   http://arxiv.org/abs/1812.03785v1            astro-ph.IM
# 21   http://arxiv.org/abs/1812.03700v1            astro-ph.SR
# 22   http://arxiv.org/abs/1812.03687v1            astro-ph.IM
# 23   http://arxiv.org/abs/1812.03575v1            astro-ph.IM
# 24   http://arxiv.org/abs/1812.03189v1            astro-ph.GA
# 25   http://arxiv.org/abs/1812.02764v1            astro-ph.HE
# 26   http://arxiv.org/abs/1812.02741v1            astro-ph.EP
# 27   http://arxiv.org/abs/1812.02454v1            astro-ph.SR
# 28   http://arxiv.org/abs/1812.02200v1            astro-ph.IM
# 29   http://arxiv.org/abs/1812.02194v1            astro-ph.HE
# ..                                 ...                    ...
# 85   http://arxiv.org/abs/1811.04118v3            astro-ph.SR
# 86   http://arxiv.org/abs/1811.03976v1            astro-ph.SR
# 87   http://arxiv.org/abs/1811.03636v1            astro-ph.EP
# 88   http://arxiv.org/abs/1811.03616v1            astro-ph.SR
# 89   http://arxiv.org/abs/1811.03104v2            astro-ph.GA
# 90   http://arxiv.org/abs/1811.03071v1            astro-ph.SR
# 91   http://arxiv.org/abs/1811.03059v1            astro-ph.GA
# 92   http://arxiv.org/abs/1811.02967v1            astro-ph.GA
# 93   http://arxiv.org/abs/1811.02905v1            astro-ph.EP
# 94   http://arxiv.org/abs/1811.04074v1            astro-ph.EP
# 95   http://arxiv.org/abs/1811.02870v1            astro-ph.GA
# 96   http://arxiv.org/abs/1811.02679v2            astro-ph.GA
# 97   http://arxiv.org/abs/1811.02310v3            astro-ph.CO
# 98   http://arxiv.org/abs/1811.02296v1            astro-ph.IM
# 99   http://arxiv.org/abs/1811.02190v1            astro-ph.HE
# 100  http://arxiv.org/abs/1811.01968v2            astro-ph.CO
# 101  http://arxiv.org/abs/1811.01880v1            astro-ph.SR
# 102  http://arxiv.org/abs/1811.01650v1            astro-ph.GA
# 103  http://arxiv.org/abs/1811.01607v1            astro-ph.SR
# 104  http://arxiv.org/abs/1811.01440v1            astro-ph.IM
# 105  http://arxiv.org/abs/1811.00984v1            astro-ph.GA
# 106  http://arxiv.org/abs/1811.00838v1            astro-ph.GA
# 107  http://arxiv.org/abs/1811.00812v2            astro-ph.GA
# 108  http://arxiv.org/abs/1811.00808v1            astro-ph.GA
# 109  http://arxiv.org/abs/1811.00766v1            astro-ph.SR
# 110  http://arxiv.org/abs/1811.00760v1            astro-ph.HE
# 111  http://arxiv.org/abs/1811.00665v1            astro-ph.SR
# 112  http://arxiv.org/abs/1811.00567v1            astro-ph.HE
# 113  http://arxiv.org/abs/1811.00523v1            astro-ph.EP
# 114  http://arxiv.org/abs/1811.00412v1            astro-ph.EP
#
#                                          arxiv_comment
# 0                             Proceedings of ADASS2018
# 1                17 pages, 5 figures, published in ApJ
# 2
# 3    18 pages, 6 figures. arXiv admin note: text ov...
# 4    17 pages, 10 figures, submitted to MNRAS, comm...
# 5        15 pages, 10 figures, accepted to ApJ Letters
# 6                                      accepted to A&A
# 7    13 pages, 7 figures, accepted for publication ...
# 8                19 pages, 9 figures, accepted by ApJL
# 9                  9 pages, 4 figures, accepted to ApJ
# 10   Accepted for publication in ApJ, 32 pages, 11 ...
# 11                     Accepted for publication by ApJ
# 12   15 pages, 8 figures, accepted for publication ...
# 13         ApJ Letters, in press. 19 pages, 11 figures
# 14                               ApJ Letters, in press
# 15         36 pages, 22 figures, ApJ Letters, in press
# 16             Accepted for publication in ApJ Letters
# 17                               ApJ Letters, in press
# 18   33 pages, 12 figures, accepted by ApJL. Table ...
# 19   ApJ Letters, in press; some figure resolutions...
# 20   6 pages, proceedings from the 8th ESA Workshop...
# 21
# 22   17 pages, 15 figures, proceedings of the SPIE ...
# 23   8 pages, proceedings from the 8th ESA Workshop...
# 24   47 pages, 9 figures, 4 tables, Accepted for pu...
# 25                               ApJ Letters, in press
# 26   70 pages, 35 figures, 22 tables, accepted by PASP
# 27               Astron. Astrophys., in press; 8 pages
# 28   Submitted to IEEE Transactions on Superconduct...
# 29   Accepted for publication in Astronomy & Astrop...
# ..                                                 ...
# 85      Accepted by ApJ, 15 pages, 7 figures, 6 tables
# 86               19 pages, 10 figures, accepted to ApJ
# 87   6 pages, 5 figures, accepted for publication i...
# 88   Splinter session summary, to appear in the pro...
# 89   Accepted to ApJ, 15 pages, 9 figures; minor co...
# 90                  22 pages, 14 figures, A&A accepted
# 91     51 pages, 25 Figures, 2 Tables, Accepted to ApJ
# 92   15 pages, 10 figures, 3 tables, accepted for p...
# 93
# 94   Accepted for publication in A&A, 11 pages, 8 f...
# 95   17 pages, 11 figures, 3 tables. Accepted for p...
# 96   15 pages, 9 Figures, accepted by Astronomy and...
# 97   67 pages. Review paper. Submitted to Space Sci...
# 98
# 99   10 pages, 8 figures, 1 table, accepted for pub...
# 100  9 pages, 9 figures, 2 tables; v2: clarificatio...
# 101               Accepted by the Astronomical Journal
# 102  Accepted in Monthly Notices of the Royal Astro...
# 103  accepted for publication in A&A, 11 pages, 6 f...
# 104  6 pages, 4 figures. Published version availabl...
# 105  18 pages, 21 figures, submitted to Astron. and...
# 106  15pages, 13 figures; accepted for publication ...
# 107              13 pages, 6 figures, submitted to ApJ
# 108  17 pages, 3 figures, 2 tables. Accepted for pu...
# 109
# 110                           To appear in ApJ Letters
# 111  5 pages, 6 figures; In the 20th Cambridge Work...
# 112  Invited review article, submitted to Galaxies;...
# 113  Submitted to Astronomy & Astrophysics, revised...
# 114             11 pages, 7 figures, accepted to MNRAS
#
# [115 rows x 8 columns]

# %%
## WRITE to excel
writer = pd.ExcelWriter('testoutput.xlsx')
df.to_excel(writer,'Sheet1')
writer.save()

# %% [markdown]
# ** TO DO **
#
# Better select of range of dates https://github.com/Mahdisadjadi/arxivscraper/blob/master/arxivscraper/arxivscraper.py
# --> Works, but gets confused between single and double digit dates.
#
# Then sync directly with Google sheets (or github?)
# https://github.com/burnash/gspread
# https://github.com/robin900/gspread-dataframe
