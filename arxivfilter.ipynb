# %% [markdown]
# ## Quick ALMA-centric Arxiv filter
#
# The goal is to find any paper on the astro-ph arxiv that uses ALMA data.
#
# For now, we search for keywords:
# * ALMA
# * mm
# * millimeter
# * millimetre
#
# Results are returned in a table format for a quick look, and also exported to an excel spreadsheet.
#
# ### Suggestions always welcome!

# %%
# %matplotlib inline

# %%
import urllib
try:
    # Python 2
    from urllib import quote_plus
    from urllib import urlencode
    from urllib import urlretrieve
except ImportError:
    # Python 3
    from urllib.parse import quote_plus
    from urllib.parse import urlencode
    from urllib.request import urlretrieve

# %%
import feedparser # (you may need to install this: conda install feedparser)
import pandas as pd
import numpy as np
import datetime
import time

# %%
#OLDER VERSION:
#url = 'http://export.arxiv.org/api/query?search_query=cat:%s+AND+%%28+all:%s+OR+all:%s+OR+all:%s+OR+all:%s+%%29&start=0&sortBy=submittedDate&sortOrder=descending'%(cat,keywords[0],keywords[1],keywords[2],keywords[3])
#data = urllib.urlopen(url).read()

# %%
## Choose the date range to search
enddate = '201901061159' #enter as yyyymmddhhmm, 
startdate = '201812011159' #if nothing, print since one month before enddate 
## should implement an option for "today", but later have problems with single digit dates
if enddate == 'today':
    now = datetime.datetime.now()
    enddate = str(now.year)+str(now.month)+str(now.day)+str(now.hour)+str(now.minute)
enddate_as_date = datetime.datetime(int(enddate[0:4]),int(enddate[4:6]),int(enddate[6:8]))
if startdate == '':
    startdate_as_date=enddate_as_date.replace(day=1)
    startdate = str(startdate_as_date.year)+str(startdate_as_date.month)+str(startdate_as_date.day)+str(startdate_as_date.hour)+str(startdate_as_date.minute)
#print('Search dates: %s:%s')%(startdate,enddate) #python2
print('Search dates: {}:{}'.format(startdate,enddate)) #python3
# Out:
# Search dates: 201812011159:201901061159

# %%
## based on code from https://github.com/lukasschwab/arxiv.py/blob/master/arxiv/arxiv.py
root_url = 'http://export.arxiv.org/api/'

def query(search_query="",
         date_from=None, 
         date_until=None,
         id_list=[], 
         prune=True, 
         start=0, 
         max_results=10, 
         sort_by="relevance", 
         sort_order="descending"):
    url_args = urlencode({"id_list": ','.join(id_list),
                          "start": start,
                          "max_results": max_results,
                          "sortBy": sort_by,
                          "sortOrder": sort_order},)
    results = feedparser.parse(root_url + 'query?search_query='+search_query + url_args)
    if results.get('status') != 200:
        # TODO: better error reporting
        raise Exception("HTTP Error " + str(results.get('status', 'no status')) + " in query")
    else:
        results = results['entries']

    return results

# %%
## Make a query
cat = 'astro-ph*'
## Here are keywords from title/abstract (full text?)
keywords = ['ALMA','millimeter','millimetre','mm']
## You could also query authors using au:authorname
sq = 'cat:%s+AND+%%28+all:%s+OR+all:%s+OR+all:%s+OR+all:%s+%%29+AND+submittedDate:[%s+TO+%s]&'\
    %(cat,keywords[0],keywords[1],keywords[2],keywords[3],startdate,enddate)
num_results = 200
results=query(search_query=sq,sort_by='submittedDate',sort_order='descending',max_results=num_results)

# %% [markdown]
# **IMPORTANT NOTE**
#
# These are not curated.  They may have *nothing* to do with ALMA, but simply have a keyword 'mm'.
#
# Later I will curate them myself as we go, and save them to a google spreadsheet (or elsewhere).

# %%
## NOW convert to dataframe for better table processing
posts = []
columns=['published','title','authors','summary','link','arxiv_primary_category','arxiv_comment']

for pp in np.arange(np.size(results)):
        try: comment=results[pp][columns[6]]
        except: comment=''  
        authorlist=[]
        for elem in results[pp][columns[2]]:
            authorlist.append(elem['name'])
        posts.append((results[pp][columns[0]], results[pp][columns[1]]\
                     , results[pp][columns[2]][0]['name'], authorlist\
                     , results[pp][columns[3]], results[pp][columns[4]]\
                     , results[pp][columns[5]]['term'], comment))
        
df = pd.DataFrame(posts, columns=[columns[0],columns[1],columns[2],'author list',columns[3],columns[4],columns[5],columns[6]]) # pass data to init

# %%
## LOOK at the table
df
# Out:
#                published                                              title  \
# 0   2019-01-03T14:55:53Z  Physics of Planet Trapping with Applications t...
# 1   2019-01-03T09:31:28Z  Can Injection Model Replenish the Filaments in...
# 2   2019-01-02T15:41:21Z  Laboratory spectroscopic study of the $^{15}$N...
# 3   2019-01-02T02:33:17Z  JCMT POL-2 and ALMA polarimetric observations ...
# 4   2019-01-01T01:12:29Z  An ALMA view of CS and SiS around oxygen-rich ...
# 5   2018-12-31T08:32:21Z         Geologic Constraints on Early Mars Climate
# 6   2018-12-30T05:18:23Z  Time Evolution of 3D Disk Formation with Misal...
# 7   2018-12-27T14:41:57Z  Indication of Another Intermediate-mass Black ...
# 8   2018-12-25T00:00:51Z  Molecular gas in radio galaxies in dense Mpc-s...
# 9   2018-12-23T21:30:08Z  ALMA Observations of the massive molecular out...
# 10  2018-12-21T16:04:47Z  Fire in the Heart: A Characterization of the H...
# 11  2018-12-21T05:21:06Z  Dusty Superwind from a Galaxy with a Compact O...
# 12  2018-12-20T14:44:22Z  Fabrication of phononic filter structures for ...
# 13  2018-12-19T08:49:08Z  Warm CO in evolved stars from the THROES catal...
# 14  2018-12-19T08:33:52Z  A 1000 AU Scale Molecular Outflow Driven by a ...
# 15  2018-12-18T19:37:02Z  ALMA polarimetric studies of rotating jet/disk...
# 16  2018-12-18T19:00:02Z  The Fornax 3D project: dust mix and gas proper...
# 17  2018-12-18T15:55:29Z    3D Radiation hydrodynamics of a dynamical torus
# 18  2018-12-18T11:00:32Z  Observations of the solar chromosphere with AL...
# 19  2018-12-18T09:26:17Z  Development of Large-area Lithium-drifted Sili...
# 20  2018-12-17T23:13:52Z  ALMA Observations of the Spatial Distribution ...
# 21  2018-12-17T21:12:01Z  Preperihelion Outbursts and Disintegration of ...
# 22  2018-12-14T19:09:30Z  [CII] 158 Micron Emission from z~4 HI Absorpti...
# 23  2018-12-14T19:00:00Z  The ISM Properties and Gas Kinematics of a Red...
# 24  2018-12-14T16:11:36Z  Internal Structures of Molecular Clouds in the...
# 25  2018-12-14T05:23:23Z                       An introduction to FITSWebQL
# 26  2018-12-13T19:00:00Z  ALMA Detection of Extended Millimeter Halos in...
# 27  2018-12-13T12:40:02Z  ALMA Observations of the Molecular Gas in the ...
# 28  2018-12-13T09:08:06Z  Dark Matter in the Central Region of the Spira...
# 17  We have developed a new dynamical model of the...
# 18  In this work we use solar observations with th...
# 19  We have developed large-area lithium-drifted s...
# 20  The C$_2$H$_4$O$_2$ isomers have been previous...
# 21  A sequence of events, dominated by two outburs...
# 22  We report on a search for the [CII] 158 micron...
# 23  We present CO(J= 1-0; 3-2; 5-4; 10-9) and 1.2-...
# 24  We observed five giant molecular clouds (GMCs)...
# 25  The JVO ALMA WebQL web service - available thr...
# 26  We present ALMA 1.3 mm (230 GHz) observations ...
# 27  We present the results of CO interferometric o...
# 28  We present our results of 12 CO(1-0) transitio...
# 29  We investigate effects of energetic pulsar win...
# ..                                                ...
# 31  The origin of the reservoirs of water on Earth...
# 32  UltraFast Outflows (UFOs), seen as X-ray blues...
# 33  We present an analysis of ALMA 1.25 millimeter...
# 34  Debris disk detections around M dwarfs are rar...
# 35  We present a catalog of 26 faint submillimeter...
# 36  The formation of planets occurs within protopl...
# 37  We present a detailed analysis of new ALMA obs...
# 38  ALMA observations of protoplanetary disks acqu...
# 39  We present a detailed analysis of the high-ang...
# 40  The Disk Substructures at High Angular Resolut...
# 41  A large fraction of the protoplanetary disks o...
# 42  The Disk Substructures at High Angular Resolut...
# 43  The Disk Substructures at High Angular Resolut...
# 44  We introduce the Disk Substructures at High An...
# 45  We report here on measurements of the reflecti...
# 46  Orion KL is one of the prime templates of astr...
# 47  In this paper we discuss the latest developmen...
# 48  The Atacama Large Millimeter/sub-millimeter Ar...
# 49  Using the $\approx$15km ALMA long baselines, w...
# 50  We report a clumpy elongated feature found wit...
# 51  The European FP7 project DIANA has performed a...
# 52  Methyl mercaptan (also known as methanethiol),...
# 53  We have developed a flexible radio-frequency r...
# 54  Investigating the magnetic field structure in ...
# 55  We present new ${}^{12}$CO(J=1-0) observations...
# 56  We carry out three-dimensional hydrodynamical ...
# 57  Young massive stars are usually found embedded...
# 58  We report the joint analysis of single-dish an...
# 59  We present the discovery of a small kinematica...
# 60  Recent derivations of the galaxy star formatio...
#
#                                  link arxiv_primary_category  \
# 0   http://arxiv.org/abs/1901.00778v1            astro-ph.EP
# 1   http://arxiv.org/abs/1901.00659v1            astro-ph.SR
# 2   http://arxiv.org/abs/1901.00421v1            astro-ph.SR
# 3   http://arxiv.org/abs/1901.00242v1            astro-ph.SR
# 4   http://arxiv.org/abs/1901.00070v1            astro-ph.SR
# 5   http://arxiv.org/abs/1812.11722v1            astro-ph.EP
# 6   http://arxiv.org/abs/1812.11471v1            astro-ph.GA
# 7   http://arxiv.org/abs/1812.10733v1            astro-ph.GA
# 8   http://arxiv.org/abs/1812.09997v1            astro-ph.GA
# 9   http://arxiv.org/abs/1812.09779v1            astro-ph.GA
# 10  http://arxiv.org/abs/1812.09219v1            astro-ph.GA
# 11  http://arxiv.org/abs/1812.08953v1            astro-ph.GA
# 12  http://arxiv.org/abs/1812.08612v1            astro-ph.IM
# 13  http://arxiv.org/abs/1812.07815v1            astro-ph.SR
# 14  http://arxiv.org/abs/1812.07806v1            astro-ph.GA
# 15  http://arxiv.org/abs/1812.07618v1            astro-ph.SR
# 16  http://arxiv.org/abs/1812.07582v1            astro-ph.GA
# 17  http://arxiv.org/abs/1812.07448v1            astro-ph.GA
# 18  http://arxiv.org/abs/1812.07293v1            astro-ph.SR
# 19  http://arxiv.org/abs/1812.07255v1            astro-ph.IM
# 20  http://arxiv.org/abs/1812.07091v2            astro-ph.GA
# 21  http://arxiv.org/abs/1812.07054v1            astro-ph.EP
# 22  http://arxiv.org/abs/1812.06113v1            astro-ph.GA
# 23  http://arxiv.org/abs/1812.06095v1            astro-ph.GA
# 24  http://arxiv.org/abs/1812.06001v1            astro-ph.GA
# 25  http://arxiv.org/abs/1812.05787v1            astro-ph.IM
# 26  http://arxiv.org/abs/1812.05610v1            astro-ph.EP
# 27  http://arxiv.org/abs/1812.05385v1            astro-ph.GA
# 28  http://arxiv.org/abs/1812.05918v1            astro-ph.GA
# 29  http://arxiv.org/abs/1812.04773v1            astro-ph.HE
# ..                                ...                    ...
# 31  http://arxiv.org/abs/1812.04357v1            astro-ph.GA
# 32  http://arxiv.org/abs/1812.04316v1            astro-ph.GA
# 33  http://arxiv.org/abs/1812.04193v1            astro-ph.SR
# 34  http://arxiv.org/abs/1812.04124v1            astro-ph.SR
# 35  http://arxiv.org/abs/1812.04108v1            astro-ph.GA
# 36  http://arxiv.org/abs/1812.04062v1            astro-ph.EP
# 37  http://arxiv.org/abs/1812.04049v1            astro-ph.SR
# 38  http://arxiv.org/abs/1812.04047v1            astro-ph.SR
# 39  http://arxiv.org/abs/1812.04046v1            astro-ph.SR
# 40  http://arxiv.org/abs/1812.04045v1            astro-ph.EP
# 41  http://arxiv.org/abs/1812.04044v1            astro-ph.EP
# 42  http://arxiv.org/abs/1812.04043v1            astro-ph.SR
# 43  http://arxiv.org/abs/1812.04041v1            astro-ph.EP
# 44  http://arxiv.org/abs/1812.04040v1            astro-ph.SR
# 45  http://arxiv.org/abs/1812.03785v1            astro-ph.IM
# 46  http://arxiv.org/abs/1812.03700v1            astro-ph.SR
# 47  http://arxiv.org/abs/1812.03687v1            astro-ph.IM
# 48  http://arxiv.org/abs/1812.03575v1            astro-ph.IM
# 49  http://arxiv.org/abs/1812.03189v1            astro-ph.GA
# 50  http://arxiv.org/abs/1812.02764v1            astro-ph.HE
# 51  http://arxiv.org/abs/1812.02741v1            astro-ph.EP
# 52  http://arxiv.org/abs/1812.02454v1            astro-ph.SR
# 53  http://arxiv.org/abs/1812.02200v1            astro-ph.IM
# 54  http://arxiv.org/abs/1812.02194v1            astro-ph.HE
# 55  http://arxiv.org/abs/1812.02180v1            astro-ph.GA
# 56  http://arxiv.org/abs/1812.01262v1            astro-ph.EP
# 57  http://arxiv.org/abs/1812.01191v2            astro-ph.GA
# 58  http://arxiv.org/abs/1812.01034v1            astro-ph.CO
# 59  http://arxiv.org/abs/1812.00809v2            astro-ph.GA
# 60  http://arxiv.org/abs/1812.00682v1            astro-ph.GA
#
#                                         arxiv_comment
# 0                   Accepted for publication in MNRAS
# 1                12 pages, 7 figures, Accepted by RAA
# 2               Astron. Astrophys., accepted; 8 pages
# 3                                     Accepted by ApJ
# 4                                            16 pages
# 5                   Accepted by Space Science Reviews
# 6   28 pages, 19 Figures and 3 Tables. Accepted fo...
# 7   Accepted for publication on the Astrophysical ...
# 8   24 pages, 9 Figures, 8 Tables, accepted for pu...
# 9   19 pages, 17 figures, 2 appendices. Accepted f...
# 10  60 pages, 25 figures (whew!), Accepted for pub...
# 11  44 pages, 12 figures, accepted for publication...
# 12          SPIE, Photonics West, 7 pages, 4 figures,
# 13                                    accepted in A&A
# 14  27 pages, 14 figures, accepted for publication...
# 15  9 pages, 3 figures, to appear in "Jet Simulati...
# 16  14 pages, 9 figures, accepted for publication ...
# 17                                   Submitted to ApJ
# 18  4 pages, presented at The 20th Cambridge Works...
# 19         submitted to IEEE NSS/MIC 2018 Proceedings
# 20                               60 pages, 16 figures
# 21                    32 pages, 21 figures, 13 tables
# 22  Accepted for publication in ApJL, 8 pages, 4 f...
# 23  32 pages, 19 figures, 7 tables. Accepted to th...
# 24                                15 pages, 8 figures
# 25                           Proceedings of ADASS2018
# 26              17 pages, 5 figures, published in ApJ
# 27
# 28  18 pages, 6 figures. arXiv admin note: text ov...
# 29  17 pages, 10 figures, submitted to MNRAS, comm...
# ..                                                ...
# 31                                    accepted to A&A
# 32  13 pages, 7 figures, accepted for publication ...
# 33              19 pages, 9 figures, accepted by ApJL
# 34                9 pages, 4 figures, accepted to ApJ
# 35  Accepted for publication in ApJ, 32 pages, 11 ...
# 36                    Accepted for publication by ApJ
# 37  15 pages, 8 figures, accepted for publication ...
# 38        ApJ Letters, in press. 19 pages, 11 figures
# 39                              ApJ Letters, in press
# 40        36 pages, 22 figures, ApJ Letters, in press
# 41            Accepted for publication in ApJ Letters
# 42                              ApJ Letters, in press
# 43  33 pages, 12 figures, accepted by ApJL. Table ...
# 44  ApJ Letters, in press; some figure resolutions...
# 45  6 pages, proceedings from the 8th ESA Workshop...
# 46
# 47  17 pages, 15 figures, proceedings of the SPIE ...
# 48  8 pages, proceedings from the 8th ESA Workshop...
# 49  47 pages, 9 figures, 4 tables, Accepted for pu...
# 50                              ApJ Letters, in press
# 51  70 pages, 35 figures, 22 tables, accepted by PASP
# 52              Astron. Astrophys., in press; 8 pages
# 53  Submitted to IEEE Transactions on Superconduct...
# 54  Accepted for publication in Astronomy & Astrop...
# 55
# 56  21 pages, 20 figures, accepted for publication...
# 57  3 pages, 3 figures, To appear in the proceedin...
# 58                                 submitted to MNRAS
# 59            Accepted for publication in A&A letters
# 60  8 pages, 6 figures, accepted for publication i...
#
# [61 rows x 8 columns]

# %%
## WRITE to excel
writer = pd.ExcelWriter('testoutput.xlsx')
df.to_excel(writer,'Sheet1')
writer.save()

# %% [markdown]
# ** TO DO **
#
# Better select of range of dates https://github.com/Mahdisadjadi/arxivscraper/blob/master/arxivscraper/arxivscraper.py
# --> Works, but gets confused between single and double digit dates.
#
# Then sync directly with Google sheets (or github?)
# https://github.com/burnash/gspread
# https://github.com/robin900/gspread-dataframe
